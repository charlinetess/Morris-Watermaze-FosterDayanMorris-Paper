# %%
using Plots

# %%
using Plots
x = 1:10; y = rand(10); # These are the plotting data
plot(x,y)

# %%
x = 1:10; y = rand(10,2) # 2 columns means two lines
plot(x,y)

# %%
z = rand(10)
plot!(x,z)

# %%
x = 1:10; y = rand(10,2) # 2 columns means two lines
p = plot(x,y)
z = rand(10)
plot!(p,x,z)

# %%
x = 1:10; y = rand(10,2) # 2 columns means two lines
plot(x,y,title="Two Lines",label=["Line 1" "Line 2"],lw=3)
xlabel!("My x label")

# %%
pyplot()
#markers = (filter((m->begin m in Plots.supported_markers() end),Plots._shape_keys))'
n = length(Plots.supported_markers())
x = (linspace(0,10,n + 2))[2:end - 1]
y = repmat((reverse(x))',n,1)
#scatter(x,y,m=(8,:auto),lab=map(string,markers),bg=:linen,xlim=(0,10),ylim=(0,10))
markers=Plots._shape_keys;
scatter(x,y,m=(8,:auto),shape=Plots.supported_markers(),bg=:linen,xlim=(0,10),ylim=(0,10))

# %%
bar(randn(99))

# %%
histogram(randn(1000),nbins=20)

# %%
# Use the layout keyword, and optionally the convenient @layout macro to generate arbitrarily complex subplot layouts.

l = @layout([a{0.1h};b [c;d e]])
plot(randn(100,5),layout=l,
     t=[:line :histogram :scatter :steppre :bar],leg=false,ticks=nothing,border=false)

# %%
l = @layout([a{0.1h};b [c; e]])
plot(randn(100,4),layout=l,
     t=[:line :histogram :scatter  :bar],leg=false,ticks=nothing,border=false)

# %%
plot(Plots.fakedata(100,10),layout=4,
     palette=[:grays :blues :heat :lightrainbow],
     bg_inside=[:orange :pink :darkblue :black])

# %%
srand(111)
plot!(Plots.fakedata(100,10))

# %%
# Open High Low Close chart : 

n = 20
hgt = rand(n) + 1
bot = randn(n)
openpct = rand(n)
closepct = rand(n)
y = OHLC[(openpct[i] * hgt[i] + bot[i],bot[i] + hgt[i],bot[i],closepct[i] * hgt[i] +
          bot[i]) for i = 1:n]
ohlc(y)

# %%
y = rand(10)
plot(y,annotations=(3,y[3],text("this is #3",:left)),leg=false)
annotate!([(5,y[5],text("this is #5",16,:red,:center)),
          (10,y[10],text("this is #10",:right,20,"courier"))])
scatter!(linspace(2,8,6),rand(6),marker=(50,0.2,:orange),
         series_annotations=["series","annotations","map","to","series",
                             text("data",:green)])
# Out:
# /Users/pmxct2/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family [u'courier'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Customed Markers 
# Plots.Shape is a light wrapper around vertices of a polygon. 

verts =[(-1.0,1.0),(-1.28,0.6),(-0.2,-1.4),(0.2,-1.4),(1.28,0.6),(1.0,1.0),(-1.0,1.0),
        (-0.2,-0.6),(0.0,-0.2),(-0.4,0.6),(1.28,0.6),(0.2,-1.4),(-0.2,-1.4),(0.6,0.2),
        (-0.2,0.2),(0.0,-0.2),(0.2,0.2),(-0.2,-0.6)]
x = 0.1:0.2:0.9
y = 0.7 * rand(5) + 0.15
plot(x,y,line=(3,:dash,:lightblue),marker=(Shape(verts),30,RGBA(0,0,0,0.2)),bg=:pink,
     fg=:darkblue,xlim=(0,1),ylim=(0,1),leg=false)

# %%
# Contour : 
x = 1:0.5:20
y = 1:0.5:10
f(x,y) = begin
        (3x + y ^ 2) * abs(sin(x) + cos(y))
    end
X = repmat(x',length(y),1)
Y = repmat(y,1,length(x))
Z = map(f,X,Y)
p1 = contour(x,y,f,fill=true)
p2 = contour(x,y,Z)#,fill=true)
plot(p1,p2)
#plot(p1)
# Out:
# /Users/pmxct2/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'label'
#   s)

# %%
# Pie charts 
x = ["Nerds","Hackers","Scientists"]
y = [0.4,0.35,0.25]
pie(x,y,title="The Julia Community",l=0.5)

# %%
# 3D Plots 

n = 100
ts = linspace(0,8π,n)
x = ts .* map(cos,ts)
y = (0.1ts) .* map(sin,ts)
z = 1:n
plot(x,y,z,zcolor=reverse(z),m=(10,0.8,:blues,stroke(0)),leg=false,cbar=true,w=5)
plot!(zeros(n),zeros(n),1:n,w=10)

# %%
# 3D Plots 

n = 100
ts = linspace(0,8π,n)
x = ts .* map(cos,ts)
y = (0.1ts) .* map(sin,ts)
z = 1:n
plot(x,y,z,zcolor=reverse(z),m=(10,0.8,:blues,stroke(10)),leg=false,cbar=true,w=5,grid=false)
#plot!(zeros(n),zeros(n),1:n,w=10)

# %%
Θ = linspace(0,1.5π,100)
r = abs.(0.1 * randn(100) + sin.(3*Θ))
plot(Θ,r,proj=:polar,m=2)

# %%
xs = [string("x",i) for i = 1:10]
ys = [string("y",i) for i = 1:4]
z = float((1:4) * (1:10)')
heatmap(xs,ys,z,aspect_ratio=1)

# %%
l = @layout([[a;b] c])
p = plot(plot([sin,cos],1,leg=false),
         scatter([atan,cos],1,leg=false),
         plot(log,1,xlims=(1,10π),ylims=(0,5),leg=false),layout=l)
anim = Animation()
for x = linspace(1,10π,100)
    plot(push!(p,x,Float64[sin(x),cos(x),atan(x),cos(x),log(x)]))
    frame(anim)

end

# %%
using Plots, ProgressMeter
pyplot(leg=false, ticks=nothing)
x = y = linspace(-5, 5, 40)
zs = zeros(0,40)
n = 100

# create a progress bar for tracking the animation generation
prog = Progress(n,1)
@gif for i in linspace(0, 2π, n)
    f(x,y) = sin(x + 10sin(i)) + cos(y)

    # create a plot with 3 subplots and a custom layout
    l = @layout [a{0.7w} b; c{0.2h}]
    p = plot(x, y, f, st = [:surface, :contourf], layout=l)
    
    # induce a slight oscillating camera angle sweep, in degrees
    plot!(p[1],camera=(15*cos(i),40))

    # add a tracking line
    fixed_x = zeros(40)
    z = map(f,fixed_x,y)
    plot!(p[1], fixed_x, y, z, line = (:black, 5, 0.2))
    vline!(p[2], [0], line = (:black, 5))

    # add to and show the tracked values over time
    zs = vcat(zs, z')
    plot!(p[3], zs, alpha = 0.2, palette = cgrad(:blues).colors)
    
    # increment the progress bar
    next!(prog)
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:02
# could not spawn `ffmpeg -v 0 -i /var/folders/0b/vqp594gs0lz109m2cg4swvg40000gq/T/tmpBrnIsF/%06d.png -vf palettegen=stats_mode=diff -y /var/folders/0b/vqp594gs0lz109m2cg4swvg40000gq/T/tmpBrnIsF/palette.bmp`: no such file or directory (ENOENT)
#
# Stacktrace:
#  [1] _jl_spawn(::String, ::Array{String,1}, ::Ptr{Void}, ::Base.Process, ::RawFD, ::RawFD, ::RawFD) at ./process.jl:360
#  [2] #373 at ./process.jl:512 [inlined]
#  [3] setup_stdio(::Base.##373#374{Cmd}, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:499
#  [4] #spawn#372(::Nullable{Base.ProcessChain}, ::Function, ::Cmd, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:511
#  [5] run(::Cmd) at ./process.jl:650
#  [6] #buildanimation#294(::Int64, ::Int64, ::Bool, ::Function, ::String, ::String, ::Bool) at /Users/pmxct2/.julia/v0.6/Plots/src/animation.jl:81
# ...

# %%
y = rand(20,3)
plot(y,xaxis=("XLABEL",(-5,30),0:2:20,:flip),background_color=RGB(0.2,0.2,0.2),leg=false)
hline!(mean(y,1) + rand(1,3),line=(4,:dash,0.6,[:lightgreen :green :darkgreen]))
vline!([5,10])
title!("TITLE")
yaxis!("YLABEL",:log10)

# %%
styles = setdiff(Plots.supported_styles(),[:auto])
plot(cumsum(randn(20,length(styles)),1),style=:auto,label=map(string,styles),w=5)

# %%
using Plots
Plots.supported_styles()
# Out:
# 5-element Array{Symbol,1}:
#  :auto
#  :solid
#  :dash
#  :dot
#  :dashdot
